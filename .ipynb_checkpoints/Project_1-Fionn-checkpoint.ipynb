# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
# from census import Census
from us import states
import json

#pip istall only needs to be ran once then this code can be removed
# !pip install -U epiweeks
import epiweeks as ew

# Census API Key
from config import api_key
# c = Census(api_key)
c = api_key
# Out:
# Collecting epiweeks
#   Downloading epiweeks-2.1.2-py3-none-any.whl (6.3 kB)
# Installing collected packages: epiweeks
# Successfully installed epiweeks-2.1.2

# %%
# Out:
# Collecting us
#   Downloading us-2.0.2.tar.gz (14 kB)
# Collecting jellyfish==0.6.1
#   Downloading jellyfish-0.6.1.tar.gz (132 kB)
# Building wheels for collected packages: us, jellyfish
#   Building wheel for us (setup.py): started
#   Building wheel for us (setup.py): finished with status 'done'
#   Created wheel for us: filename=us-2.0.2-py3-none-any.whl size=11929 sha256=a1989a75b80a2e4e091c4613d04b4294b0fc3c8dbef4cb7eca35914f02576ae5
#   Stored in directory: c:\users\fionn\appdata\local\pip\cache\wheels\07\4c\fa\a65ed0f9c00360e785327fc370eba55ca575cc3508ab13ed8e
#   Building wheel for jellyfish (setup.py): started
#   Building wheel for jellyfish (setup.py): finished with status 'done'
#   Created wheel for jellyfish: filename=jellyfish-0.6.1-py3-none-any.whl size=10380 sha256=25363078d41c11f03a1902d5d28424297cab45c77a5cd1449a41390f29700f9f
#   Stored in directory: c:\users\fionn\appdata\local\pip\cache\wheels\aa\a9\a6\359d736dbeda356e6ab8a7ff70a3db636cefe91df7d09f63dc
# Successfully built us jellyfish
# Installing collected packages: jellyfish, us
# Successfully installed jellyfish-0.6.1 us-2.0.2

# %%
#Disease CSV data: issues are traslating 'epiweek' column into a year, data frame will need to be shortened to only inlude years 2005-2010

disease_df = pd.read_csv("diseases_us_1916_to_2011.csv")

disease_df
# Out:
# C:\Users\fionn\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         epi_week state             loc loc_type      disease cases  \
# 0         196601    MN       MINNESOTA    STATE  HEPATITIS A     3
# 1         196601    CO        COLORADO    STATE  HEPATITIS A     1
# 2         196601    AZ         ARIZONA    STATE  HEPATITIS A     6
# 3         196601    MT         MONTANA    STATE  HEPATITIS A     2
# 4         196601    LA       LOUISIANA    STATE  HEPATITIS A     1
# ...          ...   ...             ...      ...          ...   ...
# 759462    194752    WI        SUPERIOR     CITY   DIPHTHERIA     0
# 759463    194752    FL           TAMPA     CITY   DIPHTHERIA     0
# 759464    194752    CO          DENVER     CITY   DIPHTHERIA     1
# 759465    194752    NY         BUFFALO     CITY   DIPHTHERIA     2
# 759466    194752    UT  SALT LAKE CITY     CITY   DIPHTHERIA     0
#
#         incidence_per_100000
# 0                       0.08
# 1                       0.05
# 2                       0.37
# 3                       0.28
# 4                       0.03
# ...                      ...
# 759462                  0.00
# 759463                  0.00
# 759464                  0.25
# 759465                  0.35
# 759466                  0.00
#
# [759467 rows x 7 columns]

# %%
#Convert epi_week column into week and years columns.
disease_df['epi_week'] = disease_df['epi_week'].astype(str)
disease_df['year'] = disease_df['epi_week'].str[0:4]
disease_df['week'] = disease_df['epi_week'].str[4:6]
disease_df
# Out:
#        epi_week state             loc loc_type      disease cases  \
# 0        196601    MN       MINNESOTA    STATE  HEPATITIS A     3
# 1        196601    CO        COLORADO    STATE  HEPATITIS A     1
# 2        196601    AZ         ARIZONA    STATE  HEPATITIS A     6
# 3        196601    MT         MONTANA    STATE  HEPATITIS A     2
# 4        196601    LA       LOUISIANA    STATE  HEPATITIS A     1
# ...         ...   ...             ...      ...          ...   ...
# 759462   194752    WI        SUPERIOR     CITY   DIPHTHERIA     0
# 759463   194752    FL           TAMPA     CITY   DIPHTHERIA     0
# 759464   194752    CO          DENVER     CITY   DIPHTHERIA     1
# 759465   194752    NY         BUFFALO     CITY   DIPHTHERIA     2
# 759466   194752    UT  SALT LAKE CITY     CITY   DIPHTHERIA     0
#
#         incidence_per_100000  year week
# 0                       0.08  1966   01
# 1                       0.05  1966   01
# 2                       0.37  1966   01
# 3                       0.28  1966   01
# 4                       0.03  1966   01
# ...                      ...   ...  ...
# 759462                  0.00  1947   52
# 759463                  0.00  1947   52
# 759464                  0.25  1947   52
# 759465                  0.35  1947   52
# 759466                  0.00  1947   52
#
# [759467 rows x 9 columns]

# %%
short_disese_df = disease_df.loc[disease_df['year'].isin(['2006','2007','2008','2009','2010'])]
# short_disese_df = disease_df.loc[(disease_df['year']== '2010')|(disease_df['year']== '2009')|(disease_df['year']== '2008')|(disease_df['year']== '2007')|(disease_df['year']== '2006')]
short_disese_df
# Out:
#        epi_week state             loc loc_type      disease cases  \
# 77860    200601    OH            OHIO    STATE  HEPATITIS A     1
# 77861    200601    MO        MISSOURI    STATE  HEPATITIS A     1
# 77862    200601    CA      CALIFORNIA    STATE  HEPATITIS A    34
# 77863    200601    FL         FLORIDA    STATE  HEPATITIS A     7
# 77864    200601    PA    PENNSYLVANIA    STATE  HEPATITIS A     1
# ...         ...   ...             ...      ...          ...   ...
# 412420   201052    OR          OREGON    STATE    PERTUSSIS     2
# 412421   201052    WI       WISCONSIN    STATE    PERTUSSIS     0
# 412422   201052    NJ      NEW JERSEY    STATE    PERTUSSIS     5
# 412423   201052    NC  NORTH CAROLINA    STATE    PERTUSSIS     0
# 412424   201052    NY        NEW YORK    STATE    PERTUSSIS    47
#
#         incidence_per_100000  year week
# 77860                   0.01  2006   01
# 77861                   0.02  2006   01
# 77862                   0.09  2006   01
# 77863                   0.04  2006   01
# 77864                   0.01  2006   01
# ...                      ...   ...  ...
# 412420                  0.05  2010   52
# 412421                  0.00  2010   52
# 412422                  0.06  2010   52
# 412423                  0.00  2010   52
# 412424                  0.24  2010   52
#
# [22500 rows x 9 columns]

# %%
# Disease CSV data: Issues with the 'cases' column being listed as an object when it should be an integer or float
disease_df.dtypes
# Out:
# epi_week                 object
# state                    object
# loc                      object
# loc_type                 object
# disease                  object
# cases                    object
# incidence_per_100000    float64
# year                     object
# week                     object
# dtype: object

# %%
#Census Data: This is how to pull household income and populaton data from the ACS5 census using the pandas census module(group has decided we will probably not use this method):
#Issues include having troube pulling multiple years as well as the state column coming in s a number rather than a state name.

census_data = c.acs5.get(("NAME", "B01003_001E","B19013_001E"), {'for': 'state:*'}, year=2010)

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B19013_001E": "Household Income",
                                      "NAME": "Name", 
                                      "state": "State"})

census_pd = census_pd[["State", "Population", "Household Income"]]
print(len(census_pd))
census_pd.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-5ab3791aec4a> in <module>
#       2 #Issues include having troube pulling multiple years as well as the state column coming in s a number rather than a state name.
#       3
# ----> 4 census_data = c.acs5.get(("NAME", "B01003_001E","B19013_001E"), {'for': 'state:*'}, year=2010)
#       5
#       6 # Convert to DataFrame
#
# AttributeError: 'str' object has no attribute 'acs5'

# %%
#Below is the alternate way to pull census income data from the ACS5 using the URL

# %%
year=[2006,2007,2008,2009,2010]
target_url = f"https://api.census.gov/data/{year}/acs/acs5?get=NAME,B01003_001E,B19013_001E&for=state:*&key={api_key}"
income_data = requests.get(target_url).json()

# %%
#print the Json data with formatting
print(json.dumps(income_data, indent=4, sort_keys=True))

# %%
#reading the census Json data into a dataframe. issues include translating the state names into state abreviations to match the disease data frame, dropping the frst row, and renaming the columns
income_df = pd.DataFrame(income_data)
income_df

# %%
#Firt row dropped
income_df.drop(index=income_df.index[0],axis=0,inplace=True)
income_df
